# %% [markdown]
# # Rossmann Store Sales
#
# https://www.kaggle.com/c/rossmann-store-sales

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100)
from pandas import datetime

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from statsmodels.distributions.empirical_distribution import ECDF
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from pylab import rcParams
rcParams['figure.figsize'] = 14, 20

# %%
from pyecharts import options as opts
from pyecharts.charts import Calendar, Bar, Line, Pie, Map, Page, ThemeRiver, Timeline, Grid, Kline, TreeMap, WordCloud, Scatter, EffectScatter
from pyecharts.components import Table
from pyecharts.options import ComponentTitleOpts
from pyecharts.commons.utils import JsCode
from pyecharts.globals import SymbolType

# %% [markdown]
# ## Load dataset

# %%
train = pd.read_csv('data/rossmann-store-sales/train.csv', parse_dates = True, index_col = 'Date')
store = pd.read_csv('data/rossmann-store-sales/store.csv')

# %%
print('In total: ', train.shape)
# Out:
# In total:  (1017209, 8)

# %%
train.head(5).append(train.tail(5))
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263        555     1      1            0
# 2015-07-31      2          5   6064        625     1      1            0
# 2015-07-31      3          5   8314        821     1      1            0
# 2015-07-31      4          5  13995       1498     1      1            0
# 2015-07-31      5          5   4822        559     1      1            0
# 2013-01-01   1111          2      0          0     0      0            a
# 2013-01-01   1112          2      0          0     0      0            a
# 2013-01-01   1113          2      0          0     0      0            a
# 2013-01-01   1114          2      0          0     0      0            a
# 2013-01-01   1115          2      0          0     0      0            a
#
#             SchoolHoliday
# Date
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-31              1
# 2013-01-01              1
# 2013-01-01              1
# 2013-01-01              1
# 2013-01-01              1
# 2013-01-01              1

# %% [markdown]
# ## Exploratory analysis

# %%
train['Year'] = train.index.year
train['Month'] = train.index.month
train['Day'] = train.index.day
train['WeekOfYear'] = train.index.weekofyear

# %%
train['SalePerCustomer'] = train['Sales']/train['Customers']

# %%
train.Store.nunique()
# Out:
# 1115

# %%
fig, axis = plt.subplots(1, 1, figsize = (12, 6))
sns.countplot(x = 'Open', hue = 'DayOfWeek', data = train)

# %%
train['Sales'].plot(kind = 'hist', bins = 100, xlim = (0, 15000))

# %% [markdown]
# ### Empirical cumulative distribution function

# %%
sns.set()
plt.figure(figsize = (15, 15))

plt.subplot(311)
cdf = ECDF(train['Sales'])
plt.plot(cdf.x, cdf.y, color = 'black')
plt.xlabel('Sales')
plt.ylabel('ECDF')

plt.subplot(312)
cdf = ECDF(train['Customers'])
plt.plot(cdf.x, cdf.y, color = 'black')
plt.xlabel('Customers')
plt.ylabel('ECDF')

plt.subplot(313)
cdf = ECDF(train['SalePerCustomer'])
plt.plot(cdf.x, cdf.y, color = 'black')
plt.xlabel('SalePerCustomer')
plt.ylabel('ECDF')
# Out:
# Text(0, 0.5, 'ECDF')

# %% [markdown]
# ### Imputation

# %%
train[(train.Open == 0) & (train.Sales == 0)].shape
# Out:
# (172817, 13)

# %%
# The store is open, but the sales is zero

zero_sales = train[(train.Open != 0) & (train.Sales == 0)]
print('In total: ', zero_sales.shape)
# Out:
# In total:  (54, 13)

# %%
zero_sales.head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-05-15    971          5      0          0     1      0            0
# 2015-03-26    674          4      0          0     1      0            0
# 2015-02-05    699          4      0          0     1      1            0
# 2014-10-01    708          3      0          0     1      1            0
# 2014-09-22    357          1      0          0     1      0            0
#
#             SchoolHoliday  Year  Month  Day  WeekOfYear  SalePerCustomer
# Date
# 2015-05-15              1  2015      5   15          20              NaN
# 2015-03-26              0  2015      3   26          13              NaN
# 2015-02-05              0  2015      2    5           6              NaN
# 2014-10-01              0  2014     10    1          40              NaN
# 2014-09-22              0  2014      9   22          39              NaN

# %%
train[(train.Open == 0) & (train.Sales != 0)]
# Out:
# Empty DataFrame
# Columns: [Store, DayOfWeek, Sales, Customers, Open, Promo, StateHoliday, SchoolHoliday, Year, Month, Day, WeekOfYear, SalePerCustomer]
# Index: []

# %%
print("Closed stores and days which did not have any sales won't be counted into the forecast.")
train = train[(train.Open != 0) & (train.Sales != 0)]

print('In total: ', train.shape)
# Out:
# Closed stores and days which did not have any sales won't be counted into the forecast.
# In total:  (844338, 13)

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
store[store['Promo2'] == 0].shape
# Out:
# (544, 10)

# %%
# Zero imputation

# %%
store.fillna({'Promo2SinceWeek': 0, 'Promo2SinceYear': 0, 'PromoInterval': 0}, inplace = True)

# %%
store[pd.isnull(store.CompetitionDistance)]
# Out:
#      Store StoreType Assortment  CompetitionDistance  \
# 290    291         d          a                  NaN
# 621    622         a          c                  NaN
# 878    879         d          a                  NaN
#
#      CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 290                        NaN                       NaN       0
# 621                        NaN                       NaN       0
# 878                        NaN                       NaN       1
#
#      Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 290              0.0              0.0                0
# 621              0.0              0.0                0
# 878              5.0           2013.0  Feb,May,Aug,Nov

# %%
plt.figure(figsize = (12, 8))
sns.distplot(store.CompetitionDistance.dropna(), color = 'black')
plt.title('CompetitionDistance Distribution')
# Out:
# Text(0.5, 1.0, 'CompetitionDistance Distribution')

# %%
# Median imputation

store['CompetitionDistance'].fillna(store['CompetitionDistance'].median(), inplace = True)

# %%
def bar(data, column, title) -> Bar:
    c = (
        Bar()
        .add_xaxis(list(data['index']))
        .add_yaxis("", list(data[column]))
        .set_global_opts(title_opts = opts.TitleOpts(title = title))
    )
    return c

# %%
CompetitionOpenSinceYear = pd.DataFrame(store['CompetitionOpenSinceYear'].value_counts()).sort_index(ascending = False).reset_index()

c = bar(CompetitionOpenSinceYear, 'CompetitionOpenSinceYear', 'CompetitionOpenSinceYear Distribution')

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d290ec132d70496686655747335c9cbe" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d290ec132d70496686655747335c9cbe = echarts.init(
#                     document.getElementById('d290ec132d70496686655747335c9cbe'), 'white', {renderer: 'canvas'});
#                 var option_d290ec132d70496686655747335c9cbe = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 38,
#                 70,
#                 83,
#                 82,
#                 54,
#                 55,
#                 54,
#                 54,
#                 48,
#                 47,
#                 62,
#                 22,
#                 19,
#                 27,
#                 16,
#                 10,
#                 8,
#                 1,
#                 2,
#                 2,
#                 5,
#                 1,
#                 1
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 2015.0,
#                 2014.0,
#                 2013.0,
#                 2012.0,
#                 2011.0,
#                 2010.0,
#                 2009.0,
#                 2008.0,
#                 2007.0,
#                 2006.0,
#                 2005.0,
#                 2004.0,
#                 2003.0,
#                 2002.0,
#                 2001.0,
#                 2000.0,
#                 1999.0,
#                 1998.0,
#                 1995.0,
#                 1994.0,
#                 1990.0,
#                 1961.0,
#                 1900.0
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "CompetitionOpenSinceYear Distribution"
#         }
#     ]
# };
#                 chart_d290ec132d70496686655747335c9cbe.setOption(option_d290ec132d70496686655747335c9cbe);
#         });
#     </script>

# %%
store[['CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear']].fillna(0, inplace = True)

# %%
print('Joining train set with an additional store information.')
train_store = pd.merge(train, store, how = 'left', on = 'Store')
print('In total: ', train_store.shape)
# Out:
# Joining train set with an additional store information.
# In total:  (844338, 22)

# %%
train_store.head()
# Out:
#    Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5   5263        555     1      1            0
# 1      2          5   6064        625     1      1            0
# 2      3          5   8314        821     1      1            0
# 3      4          5  13995       1498     1      1            0
# 4      5          5   4822        559     1      1            0
#
#    SchoolHoliday  Year  Month  Day  WeekOfYear  SalePerCustomer StoreType  \
# 0              1  2015      7   31          31         9.482883         c
# 1              1  2015      7   31          31         9.702400         a
# 2              1  2015      7   31          31        10.126675         a
# 3              1  2015      7   31          31         9.342457         c
# 4              1  2015      7   31          31         8.626118         a
#
#   Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0          a               1270.0                        9.0
# 1          a                570.0                       11.0
# 2          a              14130.0                       12.0
# 3          c                620.0                        9.0
# 4          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              0.0              0.0
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              0.0              0.0
# 4                    2015.0       0              0.0              0.0
#
#      PromoInterval
# 0                0
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3                0
# 4                0

# %%
StoreType = pd.DataFrame(store['StoreType'].value_counts()).sort_index(ascending = False).reset_index()

c = bar(StoreType, 'StoreType', 'StoreType Distribution')

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="af3fbfdfc32c44f88012710b1fc0b334" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_af3fbfdfc32c44f88012710b1fc0b334 = echarts.init(
#                     document.getElementById('af3fbfdfc32c44f88012710b1fc0b334'), 'white', {renderer: 'canvas'});
#                 var option_af3fbfdfc32c44f88012710b1fc0b334 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 348,
#                 148,
#                 17,
#                 602
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "d",
#                 "c",
#                 "b",
#                 "a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "StoreType Distribution"
#         }
#     ]
# };
#                 chart_af3fbfdfc32c44f88012710b1fc0b334.setOption(option_af3fbfdfc32c44f88012710b1fc0b334);
#         });
#     </script>

# %%
train_store.groupby('StoreType')['Sales'].describe()
# Out:
#               count          mean          std     min      25%     50%  \
# StoreType
# a          457042.0   6925.697986  3277.351589    46.0  4695.25  6285.0
# b           15560.0  10233.380141  5155.729868  1252.0  6345.75  9130.0
# c          112968.0   6933.126425  2896.958579   133.0  4916.00  6408.0
# d          258768.0   6822.300064  2556.401455   538.0  5050.00  6395.0
#
#                 75%      max
# StoreType
# a           8406.00  41551.0
# b          13184.25  38722.0
# c           8349.25  31448.0
# d           8123.25  38037.0

# %%
train_store[train_store.Sales != 0].groupby('StoreType')['Sales'].describe()
# Out:
#               count          mean          std     min      25%     50%  \
# StoreType
# a          457042.0   6925.697986  3277.351589    46.0  4695.25  6285.0
# b           15560.0  10233.380141  5155.729868  1252.0  6345.75  9130.0
# c          112968.0   6933.126425  2896.958579   133.0  4916.00  6408.0
# d          258768.0   6822.300064  2556.401455   538.0  5050.00  6395.0
#
#                 75%      max
# StoreType
# a           8406.00  41551.0
# b          13184.25  38722.0
# c           8349.25  31448.0
# d           8123.25  38037.0

# %%
train_store.groupby('StoreType')['Customers', 'Sales'].sum()
# Out:
#            Customers       Sales
# StoreType
# a          363541431  3165334859
# b           31465616   159231395
# c           92129705   783221426
# d          156904995  1765392943

# %%
np.mean(train_store[(train_store.Month == 1) & (train_store.StoreType == 'b') & (train_store.Promo == 1)])['Sales']
# Out:
# 10638.306896551725

# %%
train_store.head()
# Out:
#    Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5   5263        555     1      1            0
# 1      2          5   6064        625     1      1            0
# 2      3          5   8314        821     1      1            0
# 3      4          5  13995       1498     1      1            0
# 4      5          5   4822        559     1      1            0
#
#    SchoolHoliday  Year  Month  Day  WeekOfYear  SalePerCustomer StoreType  \
# 0              1  2015      7   31          31         9.482883         c
# 1              1  2015      7   31          31         9.702400         a
# 2              1  2015      7   31          31        10.126675         a
# 3              1  2015      7   31          31         9.342457         c
# 4              1  2015      7   31          31         8.626118         a
#
#   Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0          a               1270.0                        9.0
# 1          a                570.0                       11.0
# 2          a              14130.0                       12.0
# 3          c                620.0                        9.0
# 4          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              0.0              0.0
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              0.0              0.0
# 4                    2015.0       0              0.0              0.0
#
#      PromoInterval
# 0                0
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3                0
# 4                0

# %% [markdown]
# ### Factor plot

# %%
sns.factorplot(data = train_store,
              x = 'Month',
              y = 'Sales',
              col = 'StoreType',
              row = 'Promo')
# Out:
# C:\Users\maoja\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(data = train_store,
              x = 'Month',
              y = 'Customers',
              col = 'StoreType',
              row = 'Promo')
# Out:
# C:\Users\maoja\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(data = train_store,
              x = 'Month',
              y = 'SalePerCustomer',
              col = 'StoreType',
              row = 'Promo')
# Out:
# C:\Users\maoja\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# The sales is hightly related to Promo and StoreType.

# %%
g = sns.FacetGrid(train_store.groupby(['DayOfWeek','StoreType', 'Month'], as_index = False)['Sales'].mean(),
                 col = 'DayOfWeek', row = 'StoreType', height = 4)
g.map(plt.plot, 'Month', 'Sales', marker = '.')

# %%
train_store[(train_store.Open == 1) & (train_store.DayOfWeek == 7)]['Store'].unique()
# Out:
# array([  85,  122,  209,  259,  262,  274,  299,  310,  335,  353,  423,
#         433,  453,  494,  512,  524,  530,  562,  578,  676,  682,  732,
#         733,  769,  863,  867,  931,  948, 1045, 1081, 1097, 1099,  877],
#       dtype=int64)

# %%
train_store.head()
# Out:
#    Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5   5263        555     1      1            0
# 1      2          5   6064        625     1      1            0
# 2      3          5   8314        821     1      1            0
# 3      4          5  13995       1498     1      1            0
# 4      5          5   4822        559     1      1            0
#
#    SchoolHoliday  Year  Month  Day  WeekOfYear  SalePerCustomer StoreType  \
# 0              1  2015      7   31          31         9.482883         c
# 1              1  2015      7   31          31         9.702400         a
# 2              1  2015      7   31          31        10.126675         a
# 3              1  2015      7   31          31         9.342457         c
# 4              1  2015      7   31          31         8.626118         a
#
#   Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0          a               1270.0                        9.0
# 1          a                570.0                       11.0
# 2          a              14130.0                       12.0
# 3          c                620.0                        9.0
# 4          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              0.0              0.0
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              0.0              0.0
# 4                    2015.0       0              0.0              0.0
#
#      PromoInterval
# 0                0
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3                0
# 4                0

# %%
sns.factorplot(data = train_store,
              x = 'Month',
              y = 'Sales',
              row = 'Promo2')
# Out:
# C:\Users\maoja\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
g = sns.FacetGrid(train_store.groupby(['Promo', 'Promo2', 'DayOfWeek'], as_index = False)['Sales'].mean(),
                 col = 'Promo', row = 'Promo2', height = 5)
g.map(plt.plot, 'DayOfWeek', 'Sales', marker = '.')

# %%
Assortment = pd.DataFrame(store['Assortment'].value_counts()).sort_index(ascending = False).reset_index()

c = bar(Assortment, 'Assortment', 'Assortment Distribution')
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c8b19903a59146cdace32c37cf8d5d9e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c8b19903a59146cdace32c37cf8d5d9e = echarts.init(
#                     document.getElementById('c8b19903a59146cdace32c37cf8d5d9e'), 'white', {renderer: 'canvas'});
#                 var option_c8b19903a59146cdace32c37cf8d5d9e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 513,
#                 9,
#                 593
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "c",
#                 "b",
#                 "a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Assortment Distribution"
#         }
#     ]
# };
#                 chart_c8b19903a59146cdace32c37cf8d5d9e.setOption(option_c8b19903a59146cdace32c37cf8d5d9e);
#         });
#     </script>

# %%
sns.barplot(x = 'Assortment', y = 'Sales', data = train_store, hue = 'StoreType')
